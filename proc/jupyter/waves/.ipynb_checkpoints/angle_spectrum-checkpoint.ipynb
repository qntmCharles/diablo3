# %%
import h5py, sys, os
import numpy as np
from scipy import ndimage
import scipy
from matplotlib import pyplot as plt
from matplotlib import animation
from datetime import datetime
from matplotlib import colors
print(os.getcwd())

# PyDMD imports
from pydmd import DMD, MrDMD, FbDMD, SpDMD, BOPDMD
from pydmd.plotter import plot_eigs, plot_summary, plot_modes_2D, plot_eigs_mrdmd

# %matplotlib widget

save = True

from jfunctions import *

# Get directory locations from param file
base_dir, run_dir, save_dir, version = read_params("./params.dat")

# Load simulation metadata
md = get_metadata()

# Load grids
gxf, gyf, gzf, dzf = get_grid(md)
gx, gy, gz, dz = get_grid(md, fractional_grid=False)
# Out:
# /mhome/damtp/q/cwp29/diablo3/proc/jupyter/waves

# %%
print(base_dir)

#Load simulation data
u, w, b, phi, zeta, times = load_data('u_xz', 'w_xz', 'th1_xz', 'th2_xz', 'omegaY_xz')
N2t = np.gradient(np.gradient(b, gzf, axis=1), times, axis=0)
b -= b[0] # subtract initial profile so b is perturbation b
NSAMP = len(times)

print(w.shape)

times, t0_idx = calibrate_time(save_dir, times)
# Out:
# /store/ATMOS/cwp29/data/waves/wide/hres/N_1/
# Keys: <KeysViewHDF5 ['epsilon_xy', 'epsilon_xz', 'epsilon_yz', 'kappa_t1_xy', 'kappa_t1_xz', 'kappa_t1_yz', 'kappa_t2_xy', 'kappa_t2_xz', 'kappa_t2_yz', 'nlwf_xz', 'nu_t_xy', 'nu_t_xz', 'nu_t_yz', 'omegaX_xy', 'omegaX_xz', 'omegaX_yz', 'omegaY_xy', 'omegaY_xz', 'omegaY_yz', 'omegaZ_xy', 'omegaZ_xz', 'omegaZ_yz', 'th1_xy', 'th1_xz', 'th1_yz', 'th2_xy', 'th2_xz', 'th2_yz', 'u_xy', 'u_xz', 'u_yz', 'v_xy', 'v_xz', 'v_yz', 'w_xy', 'w_xz', 'w_yz']>
# /alt/applic/user-maint/cwp29/Conda/envs/python/lib/python3.11/site-packages/numpy/lib/function_base.py:1242: RuntimeWarning: divide by zero encountered in divide
#   a = -(dx2)/(dx1 * (dx1 + dx2))
# /alt/applic/user-maint/cwp29/Conda/envs/python/lib/python3.11/site-packages/numpy/lib/function_base.py:1244: RuntimeWarning: divide by zero encountered in divide
#   c = dx1 / (dx2 * (dx1 + dx2))
# ...

# %%
buoy_per = round(2*np.pi/np.sqrt(md['N2']),1)
md['TIME_LIMIT'] = (md['FINE_RES_TIME'] + md['NBUOY_PERIODS'])*buoy_per
md['SAVE_STATS_DT'] *= buoy_per
md['SAVE_STATS_DT_FINE'] *= buoy_per
tend_idx = len(times)-1
tstart_idx = get_index(md['FINE_RES_TIME']*buoy_per, times)
print(md['TIME_LIMIT'], md['FINE_RES_TIME']*buoy_per)
print("Time range: {0:.2f} to {1:.2f} s".format(times[tstart_idx], times[tend_idx]))
print("equal to {0:.2f} buoyancy periods".format((times[tend_idx]-times[tstart_idx])/buoy_per))

#zplot = 0.4
zmin = 0.3
zmax = 0.5
zmin_idx = get_index(zmin, gzf)
zmax_idx = get_index(zmax, gzf)
gz_trunc = gz[zmin_idx-1:zmax_idx+2]
gzf_trunc = gzf[zmin_idx-1:zmax_idx+1]

xmin = 0.3
xmax = 0.7
xlims = (xmin, xmax)
xmin_idx = get_index(xmin, gxf)
xmax_idx = get_index(xmax, gxf)
gx_trunc = gx[zmin_idx-1:zmax_idx+2]
gxf_trunc = gxf[zmin_idx-1:zmax_idx+1]

zplot = 0.4 # must be smaller than z_max
xplot = 0.65 # must be smaller than x_max
assert zplot <= zmax


phi_contour = 1e-3
clim = 1e-3

# Choose data window
u = u[tstart_idx:tend_idx+1, zmin_idx:zmax_idx+1, xmin_idx:xmax_idx+1]
w = w[tstart_idx:tend_idx+1, zmin_idx:zmax_idx+1, xmin_idx:xmax_idx+1]
b = b[tstart_idx:tend_idx+1, zmin_idx:zmax_idx+1, xmin_idx:xmax_idx+1]
zeta = zeta[tstart_idx:tend_idx+1, zmin_idx:zmax_idx+1, xmin_idx:xmax_idx+1]
N2t = N2t[tstart_idx:tend_idx+1, zmin_idx:zmax_idx+1, xmin_idx:xmax_idx+1]
phi = phi[tstart_idx:tend_idx+1, zmin_idx:zmax_idx+1, xmin_idx:xmax_idx+1]
times = times[tstart_idx:tend_idx+1]

# Filter out timesteps
filter_step = 1
times = times[::filter_step]
times_trunc = np.concatenate(([times[0]-filter_step*md['SAVE_STATS_DT_FINE']], times))
ntimes = len(times)

print(len(times))

phi_snapshots = [phi[::filter_step][i] for i in range(len(times))]

X, Y = np.meshgrid(gx[xmin_idx-1:xmax_idx+1], gz[zmin_idx-1:zmax_idx+1], indexing='ij')
Xf, Yf = np.meshgrid(gxf[xmin_idx:xmax_idx+1], gzf[zmin_idx:zmax_idx+1], indexing='ij')
# Out:
# 25.2 6.3
# Time range: 6.30 to 25.07 s
# equal to 2.98 buoyancy periods
# 150

# %%
# Set up FT arrays
freq_m = -np.fft.fftfreq(tend_idx-tstart_idx+1)*2*np.pi/md['SAVE_STATS_DT_FINE']
wavenumber_z = np.fft.fftfreq(w.shape[1])*2*np.pi*md['Nz']/md['LZ']
wavenumber_x = np.fft.fftfreq(w.shape[2])*2*np.pi*md['Nx']/md['LX']

# %%
# Pre-processing & data array setup
data_pack = [u, w, N2t, zeta]
data_orig = np.array(data_pack)
data_orig = np.moveaxis(data_orig, 0, -1)

plot_idx = 3

for i in range(len(data_pack)):
    var = data_pack[i]
    
    # Gaussian filtering
    sigma = 2
    var_filtered = np.zeros_like(var)
    for j in range(len(var)):
        var_filtered[j] = ndimage.gaussian_filter(var[j], sigma)

    # Hilbert transform
    # Dimension sizes from large to small: x, z, t

    # FFT in x
    waves_x = np.fft.fft(var_filtered, axis=2)
    waves_x[:, :, np.abs(wavenumber_x) >= 1000] = 0 #remove small wavelength oscillations
    waves_filtered = np.fft.ifft(waves_x, axis=2)

    # FFT in z
    waves_z = np.fft.fft(waves_filtered, axis=1)
    #waves_z[:, wavenumber_z >= 0, :] = 0 #remove upward propagating waves
    waves_filtered = np.fft.ifft(waves_z, axis=1)
    
    waves_t = np.fft.fft(waves_filtered, axis=0)
    #waves_t[freq_m <= 0, :, :] = 0 # zero out negative freq.
    #waves_t *= 2 # preserve energy
    waves_filtered = np.real(np.fft.ifft(waves_t, axis=0))

    data_pack[i] = waves_filtered

data = np.array(data_pack)
print(data.shape)
data = np.moveaxis(data, 0, -1)
print(data.shape)

#data = np.concatenate(tuple(data_pack), axis=1)
#print(data_pack[0].shape, data.shape)
#unpacked_data = np.array_split(data, len(data_pack), axis=1)
# Out:
# (4, 150, 172, 410)
# (150, 172, 410, 4)

# %%
snapshots = [data[::filter_step][i] for i in range(len(times))]
print(snapshots[0].shape)
print(len(snapshots))

snapshots = np.array(snapshots)
snapshots = np.swapaxes(snapshots, 1, 2)
# Out:
# (172, 410, 4)
# 150

# %%
def angle_spectrum(input_data, nbins=15):
    # Assumes input_data is 2D with dimensions (x, z)
    data_fft = np.fft.fft2(input_data, axes=(0,1))
    data_fft = np.fft.fftshift(data_fft)

    kz = np.fft.fftfreq(input_data.shape[1])*2*np.pi*md['Nz']/md['LZ']
    kz = np.fft.fftshift(kz)
    kx = np.fft.fftfreq(input_data.shape[0])*2*np.pi*md['Nx']/md['LX']
    kx = np.fft.fftshift(kx)
    
    power = np.power(np.abs(data_fft), 2)
    KX, KZ = np.meshgrid(kx, kz, indexing='ij')
    
    radius = np.sqrt(np.power(KX, 2) + np.power(KZ, 2)) 
    angle = np.arccos(np.abs(KX) / radius)
    
    theta_bins = np.linspace(0, np.pi/2, nbins)

    spectrum = []
    for i in range(len(theta_bins)-1):
        spectrum.append(np.nansum(np.where(np.logical_and(angle >= theta_bins[i], angle <= theta_bins[i+1]), power, np.nan)))

    theta_plot = 0.5*(theta_bins[1:] + theta_bins[:-1])

    return np.cos(theta_plot), spectrum

# %%
tplot = 50
t_idx = get_index(tplot, times)

data_fft = np.fft.fft2(snapshots[t_idx], axes=(0,1))
data_fft = np.fft.fftshift(data_fft)

kz = np.fft.fftfreq(snapshots[t_idx].shape[1])*2*np.pi*md['Nz']/md['LZ']
kz = np.fft.fftshift(kz)
kx = np.fft.fftfreq(snapshots[t_idx].shape[0])*2*np.pi*md['Nx']/md['LX']
kx = np.fft.fftshift(kx)

# %%
fig, ax = plt.subplots(1,2, figsize=(12,6))

im_waves = ax[0].pcolormesh(X, Y, snapshots[t_idx][:,:,plot_idx], cmap='bwr', norm=colors.CenteredNorm())
im_waves.set_clim(-1e-2, 1e-2)
ax[0].set_aspect(1)

power = np.power(np.abs(data_fft[:,:,plot_idx]), 2)
print(power.shape)
print(power.dtype)
KX, KZ = np.meshgrid(kx, kz, indexing='ij')
ax[1].pcolormesh(KX, KZ, power)

plt.show()
# Out:
# (410, 172)
# float64
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
radius = np.sqrt(np.power(KX, 2) + np.power(KZ, 2))
angle = np.arccos(np.abs(KX) / radius)

fig = plt.figure()
im = plt.pcolormesh(KX, KZ, angle)
plt.colorbar(im)
# Out:
# /tmp/ipykernel_59927/1277379202.py:2: RuntimeWarning: invalid value encountered in divide
#   angle = np.arccos(np.abs(KX) / radius)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
theta_bins = np.linspace(0, np.pi/2, 11)

spectrum = []

for i in range(len(theta_bins)-1):
    spectrum.append(np.nansum(np.where(np.logical_and(angle >= theta_bins[i], angle <= theta_bins[i+1]), power, np.nan)))

theta_plot = 0.5*(theta_bins[1:] + theta_bins[:-1])

plt.figure()
plt.plot(np.cos(theta_plot), spectrum)
plt.xlabel(r"$\omega/N$")
plt.ylabel("power")
# Out:
# Text(0, 0.5, 'power')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
for nbins in [5, 9, 15, 51]:
    plt.plot(*angle_spectrum(snapshots[t_idx, :, :, plot_idx], nbins), label=nbins)
plt.legend()
# Out:
# /tmp/ipykernel_59927/1705091401.py:15: RuntimeWarning: invalid value encountered in divide
#   angle = np.arccos(np.abs(KX) / radius)

# %%
var1 = snapshots
# print("Setting up data arrays...")
fig, axs = plt.subplots(1,2,figsize=(15, 10))
ims = np.array([None,None])
cb = np.array([None,None])

print("Setting up initial plot...")
ims[0] = axs[0].pcolormesh(X, Y, var1[-1,:,:,plot_idx], cmap='bwr', norm=colors.CenteredNorm())
line1, = axs[1].plot(*angle_spectrum(var1[-1,:,:,0]), label=r"$u$")
line2, = axs[1].plot(*angle_spectrum(var1[-1,:,:,1]), label=r"$w$")
line3, = axs[1].plot(*angle_spectrum(var1[-1,:,:,2]), label=r"$\partial_{zt} b$")
line4, = axs[1].plot(*angle_spectrum(var1[-1,:,:,3]), label=r"$\zeta$")

axs[1].legend()

cb[0] = plt.colorbar(ims[0],ax=axs[0])

ims[0].set_clim(0, 3e-1)

fig.suptitle("time = 0 secs")
axs[0].set_ylabel("$z$")
axs[1].set_ylabel("power")
axs[1].set_xlabel(r"$\omega/N$")
axs[0].set_xlabel("$y$")

axs[0].set_aspect(1)

def animate(step):
    _, spectrum1 = angle_spectrum(var1[step,:,:,0])
    _, spectrum2 = angle_spectrum(var1[step,:,:,1])
    _, spectrum3 = angle_spectrum(var1[step,:,:,2])
    _, spectrum4 = angle_spectrum(var1[step,:,:,3])
    ims[0].set_array(var1[step,:,:,plot_idx].ravel())
    line1.set_ydata(spectrum1/np.trapz(np.flip(spectrum1), np.flip(freqs)))#/np.max(spectrum1))
    line2.set_ydata(spectrum2/np.trapz(np.flip(spectrum2), np.flip(freqs)))#/np.max(spectrum2))
    line3.set_ydata(spectrum3/np.trapz(np.flip(spectrum3), np.flip(freqs)))#/np.max(spectrum3))
    line4.set_ydata(spectrum4/np.trapz(np.flip(spectrum4), np.flip(freqs)))#/np.max(spectrum4))
    
    fig.suptitle("time = {0:.2f} secs".format(times[step]))

    axs[1].set_ylim(0, 5)

    return ims[0], line1, line2, line3, line4

#print("Initialising mp4 writer...")
Writer = animation.writers['ffmpeg']
writer = Writer(fps=20, bitrate=1800)

print("Starting plot...")
anim = animation.FuncAnimation(fig, animate, interval=1000*md['SAVE_STATS_DT_FINE'], frames=len(var1), repeat=True)
now = datetime.now()
#anim.save(save_dir+'shear_%s.mp4'%now.strftime("%d-%m-%Y"),writer=writer)

plt.show()
save_fig(anim, '/home/cwp29/tmp/angle_spectrum.mp4', anim=True, dpi=300)
# Out:
# Setting up initial plot...
# Starting plot...
# /tmp/ipykernel_59927/1705091401.py:15: RuntimeWarning: invalid value encountered in divide
#   angle = np.arccos(np.abs(KX) / radius)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# /tmp/ipykernel_59927/1705091401.py:15: RuntimeWarning: invalid value encountered in divide
#   angle = np.arccos(np.abs(KX) / radius)
